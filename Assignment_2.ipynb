# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv(r'C:\Manisha\DSA\Working Files\StudentsPerformance.csv')

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score
# ...

# %% [markdown]
# # How many males and females participated in the test?

# %%
data.pivot_table(index = ['gender'], aggfunc ='size')
# Out:
# gender
# female    518
# male      482
# dtype: int64

# %% [markdown]
# # Students' parental level of education

# %%
y=data['parental level of education'].value_counts()
mylabels=data['parental level of education'].unique().tolist()

# %%
plt.pie(y,labels=mylabels,radius=1)
plt.show()
print(y)
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %% [markdown]
# # Who scores the most on average for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
group = data.groupby(['gender', 'test preparation course'])

# %%
output = group['reading score', 'writing score', 'math score'].mean()

print(output)
# Out:
#                                 reading score  writing score  math score
# gender test preparation course
# female completed                    77.375000      78.793478   67.108696
#        none                         69.955090      68.982036   61.320359
# male   completed                    70.793103      70.339080   72.988506
#        none                         62.581169      59.551948   66.467532
# C:\Users\USER\AppData\Local\Temp\ipykernel_8252\2835782175.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   output = group['reading score', 'writing score', 'math score'].mean()

# %% [markdown]
# # What do you think about the scoring variation for math, reading and writing based on
# ● Gender
# ● Test preparation course

# %%
sns.scatterplot(data=data, x='math score', y='reading score', hue='test preparation course', style='gender')
# Out:
# <Axes: xlabel='math score', ylabel='reading score'>

# %%
sns.scatterplot(data=data, x='math score', y='writing score', hue='test preparation course', style='gender')
# Out:
# <Axes: xlabel='math score', ylabel='writing score'>

# %% [markdown]
# # The management needs your help to give bonus points to the top 25% of students based on their math score, so how will you help the management to achieve this

# %%
threshold = data['math score'].quantile(0.75)

# %%
data.loc[data['math score'] >= threshold, 'bonus points'] = 10

# %%
data
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C            some high school  free/reduced
# 1    female        group B                 high school  free/reduced
# 2    female        group B            some high school  free/reduced
# 3    female        group B                some college      standard
# 4    female        group C                some college  free/reduced
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...

# %%
data[data['bonus points'].notnull()]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 414  female        group A                 high school  free/reduced
# 415  female        group B             master's degree  free/reduced
# 416  female        group B           bachelor's degree  free/reduced
# 417  female        group B             master's degree      standard
# 418  female        group B                 high school      standard
# ..      ...            ...                         ...           ...
# 995    male        group E                some college      standard
# 996    male        group A                some college      standard
# 997    male        group D                some college      standard
# 998    male        group E          associate's degree  free/reduced
# 999    male        group E           bachelor's degree      standard
#
#     test preparation course  math score  reading score  writing score  \
# ...
