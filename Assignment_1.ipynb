# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Read the dataset

# %%
data=pd.read_excel(r'C:\Manisha\DSA\Working Files\iris.xls')

# %%
data
# Out:
#       SL   SW   PL   PW  Classification
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# # Display the columns

# %%
data.columns
# Out:
# Index(['SL', 'SW', 'PL', 'PW', 'Classification'], dtype='object')

# %% [markdown]
# # Calculate the mean of each column

# %%
a=data.columns

# %%
data[a].mean()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12132\1660247304.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data[a].mean()
# SL    5.843333
# SW    3.054000
# PL    3.758667
# PW    1.198667
# dtype: float64

# %% [markdown]
# # Check for the null values present

# %%
data.isnull().sum()
# Out:
# SL                0
# SW                0
# PL                0
# PW                0
# Classification    0
# dtype: int64

# %% [markdown]
# # Visualizations

# %%
# Histogram

data['SW'].hist()
# Out:
# <Axes: >

# %%
data['SL'].hist()
# Out:
# <Axes: >

# %%
data['PW'].hist()
# Out:
# <Axes: >

# %%
data['PL'].hist()
# Out:
# <Axes: >

# %%
# Pie Chart

y=data['Classification'].value_counts()
mylabels=data['Classification'].unique().tolist()

# %%
plt.pie(y,labels=mylabels,radius=1)
plt.show()
print(y)
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Classification, dtype: int64

# %%
#Correlation 

corr_matrix=data.corr()
sns.heatmap(corr_matrix,annot=True,cmap='PiYG')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_12132\459163084.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix=data.corr()
# <Axes: >

# %%
#Scatter based on classification

colors=['Red','Green','Blue']
Classification=['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    x=data[data['Classification']==Classification[i]]
    plt.scatter(x['SL'],x['SW'],color=colors[i],label=Classification[i])
    plt.xlabel("SL")
    plt.ylabel("SW")
    plt.legend()

# %%
colors=['Red','Green','Blue']
Classification=['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    x=data[data['Classification']==Classification[i]]
    plt.scatter(x['PL'],x['PW'],color=colors[i],label=Classification[i])
    plt.xlabel("PL")
    plt.ylabel("PW")
    plt.legend()

# %%
#Countplot for Iris-setosa Septal Length

data_set1=data.head(50)
sns.countplot(x=data_set1['SL'])
plt.xticks(rotation=90)
plt.show()
